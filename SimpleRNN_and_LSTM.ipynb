# %% [markdown]
# <a href="https://colab.research.google.com/github/harnalashok/deeplearning-sequences/blob/main/SimpleRNN_and_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## RNNs representations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another picture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another picture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another Picture<br>
# Boxed network is RNN. Outside box, hidden output of each RNN can be processed as one wishes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Tensorflow keras SimpleRNN syntax
#
#
#
# tf.keras.layers.SimpleRNN(<br>
# &nbsp;&nbsp;&nbsp;&nbsp;<b>units</b>,<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;activation='tanh',<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;use_bias=True,<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;bias_initializer='zeros',<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;kernel_initializer='glorot_uniform',<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;recurrent_initializer='orthogonal',<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;dropout=0.0,<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;recurrent_dropout=0.0,<br>
#     &nbsp;&nbsp;&nbsp;&nbsp;<b>return_sequences=False,</b><br>
#  )<br>

# %%
# Keras RNN syntax:

tf.keras.layers.SimpleRNN(
    units,
    activation='tanh',
    use_bias=True,
    bias_initializer='zeros',
    kernel_initializer='glorot_uniform',
    recurrent_initializer='orthogonal',
    dropout=0.0,
    recurrent_dropout=0.0,
    return_sequences=False,
 )

# %% [markdown]
# RNN for sequence classification

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## LSTM

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Below network represents one of the networks of three sigma networks

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The following diagram shows the size of input/output vectors at various points.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# tf.keras.layers.LSTM(<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>units,</b><br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;activation='tanh',<br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;recurrent_activation='sigmoid',<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;use_bias=True,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;kernel_initializer='glorot_uniform',<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;recurrent_initializer='orthogonal',<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;bias_initializer='zeros',<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;unit_forget_bias=True,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;recurrent_regularizer=None,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;dropout=0.0,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;recurrent_dropout=0.0,<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<b>return_sequences=False,</b><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;return_state=False,<br>
# )
